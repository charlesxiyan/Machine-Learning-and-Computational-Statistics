# %% [markdown]
# # Intro to Pandas
#
# This is a short introduction to pandas based on the [10 Minutes to pandas](http://pandas.pydata.org/pandas-docs/stable/10min.html) geared mainly for new users along with a few addition based on the [Cookbook](http://pandas.pydata.org/pandas-docs/stable/cookbook.html#cookbook) recipes

# %% [markdown]
# Customarily, we import as follows:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %% [markdown]
# ## Object Creation
#
# See the [Data Structure Intro section](http://pandas.pydata.org/pandas-docs/stable/dsintro.html#dsintro)

# %% [markdown]
# ### Series
# Creating a Series by passing a list of values, letting pandas create a default integer index:

# %%
s = pd.Series([1,3,5,np.nan, 6,8])

# %%
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %% [markdown]
# Series is very similar to numpy array but the index of a series is an additional class attribute

# %%
s.values # values of the series - a numpy arry
# Out:
# array([ 1.,  3.,  5., nan,  6.,  8.])

# %%
s.index # index of the series
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %% [markdown]
# ### Dataframes
#
# Creating a DataFrame by passing a numpy array, with a datetime index and labeled columns:

# %%
dates = pd.date_range('20130101', periods=6)

# %%
dates
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[us]', freq='D')

# %% [markdown]
# A Dataframe has:
#     - index
#     - values
#     - column names
#     - is a generalization of an excel table

# %%
# df = pd.DataFrame(np.random.randn(6,4))
df = pd.DataFrame(np.random.randn(6,4), index=dates, columns=list('ABCD'))
df
# Out:
#                    A         B         C         D
# 2013-01-01  0.558480  0.863395  1.185102  2.349155
# 2013-01-02 -1.551845  0.286379 -0.229315  0.576123
# 2013-01-03 -0.358542 -0.355383 -0.067001  0.351484
# 2013-01-04 -0.294955  0.006319  0.918337 -3.084601
# 2013-01-05 -1.735809  0.104906  0.588369  1.372278
# 2013-01-06 -0.364734  1.555375 -0.497573 -0.281790

# %% [markdown]
# Creating a DataFrame by passing a dict of objects that can be converted to series-like.

# %%
df2 = pd.DataFrame({'A':1.,
                   'B':pd.Timestamp('20130102'),
                   'C':pd.Series(1,index=list(range(4)),dtype='float32'),
                   'D':np.array([3]*4,dtype='int32'),
                   'E':pd.Categorical(["test","train","test","train"]),
                   'F':'foo'})
df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %% [markdown]
# Having specific [dtypes](http://pandas.pydata.org/pandas-docs/stable/basics.html#basics-dtypes)

# %%
df2.F
# Out:
# 0    foo
# 1    foo
# 2    foo
# 3    foo
# Name: F, dtype: str

# %% [markdown]
# If you’re using IPython, tab completion for column names (as well as public attributes) is automatically enabled. Here’s a subset of the attributes that will be completed:

# %% [markdown]
# As you can see, the columns A, B, C, and D are automatically tab completed. E is there as well; the rest of the attributes have been truncated for brevity.

# %% [markdown]
# ## Viewing Data
#
# See the [Basics section](http://pandas.pydata.org/pandas-docs/stable/basics.html#basics)

# %% [markdown]
# See the top & bottom rows of the frame

# %%
df.head(2)
# Out:
#                    A         B         C         D
# 2013-01-01  0.558480  0.863395  1.185102  2.349155
# 2013-01-02 -1.551845  0.286379 -0.229315  0.576123

# %%
df.tail(2)
# Out:
#                    A         B         C         D
# 2013-01-05 -1.735809  0.104906  0.588369  1.372278
# 2013-01-06 -0.364734  1.555375 -0.497573 -0.281790

# %% [markdown]
# Display the index, columns, and the underlying numpy data

# %%
df.reset_index().set_index('A').sort_index()
# Out:
#                index         B         C         D
# A
# -1.735809 2013-01-05  0.104906  0.588369  1.372278
# -1.551845 2013-01-02  0.286379 -0.229315  0.576123
# -0.364734 2013-01-06  1.555375 -0.497573 -0.281790
# -0.358542 2013-01-03 -0.355383 -0.067001  0.351484
# -0.294955 2013-01-04  0.006319  0.918337 -3.084601
#  0.558480 2013-01-01  0.863395  1.185102  2.349155

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='str')

# %%
df.values
# Out:
# array([[ 0.5584805 ,  0.86339475,  1.18510183,  2.34915543],
#        [-1.55184504,  0.28637859, -0.22931466,  0.57612267],
#        [-0.3585416 , -0.35538296, -0.06700082,  0.35148408],
#        [-0.2949549 ,  0.00631885,  0.9183368 , -3.08460137],
#        [-1.73580863,  0.10490626,  0.58836852,  1.37227832],
#        [-0.3647345 ,  1.55537548, -0.49757346, -0.28178955]])

# %% [markdown]
# Describe shows a quick statistic summary of the numeric columns of the data

# %%
df.describe()
# Out:
#               A         B         C         D
# count  6.000000  6.000000  6.000000  6.000000
# mean  -0.624567  0.410165  0.316320  0.213775
# std    0.865012  0.689142  0.677981  1.853489
# min   -1.735809 -0.355383 -0.497573 -3.084601
# 25%   -1.255067  0.030966 -0.188736 -0.123471
# 50%   -0.361638  0.195642  0.260684  0.463803
# 75%   -0.310852  0.719141  0.835845  1.173239
# max    0.558480  1.555375  1.185102  2.349155

# %% [markdown]
# Transposing your data

# %%
df.T
# Out:
#    2013-01-01  2013-01-02  2013-01-03  2013-01-04  2013-01-05  2013-01-06
# A    0.558480   -1.551845   -0.358542   -0.294955   -1.735809   -0.364734
# B    0.863395    0.286379   -0.355383    0.006319    0.104906    1.555375
# C    1.185102   -0.229315   -0.067001    0.918337    0.588369   -0.497573
# D    2.349155    0.576123    0.351484   -3.084601    1.372278   -0.281790

# %% [markdown]
# Sorting by an axis

# %%
df.reset_index().rename(columns={'index':'date'}).set_index(['date', 'A']).sort_index(axis=0, ascending=True)
# Out:
#                              B         C         D
# date       A
# 2013-01-01  0.558480  0.863395  1.185102  2.349155
# 2013-01-02 -1.551845  0.286379 -0.229315  0.576123
# 2013-01-03 -0.358542 -0.355383 -0.067001  0.351484
# 2013-01-04 -0.294955  0.006319  0.918337 -3.084601
# 2013-01-05 -1.735809  0.104906  0.588369  1.372278
# 2013-01-06 -0.364734  1.555375 -0.497573 -0.281790

# %%
df.sort_index(axis=1, ascending=False)
# Out:
#                    D         C         B         A
# 2013-01-01  2.349155  1.185102  0.863395  0.558480
# 2013-01-02  0.576123 -0.229315  0.286379 -1.551845
# 2013-01-03  0.351484 -0.067001 -0.355383 -0.358542
# 2013-01-04 -3.084601  0.918337  0.006319 -0.294955
# 2013-01-05  1.372278  0.588369  0.104906 -1.735809
# 2013-01-06 -0.281790 -0.497573  1.555375 -0.364734

# %% [markdown]
# Sorting by value

# %%
df.sort_values(by='B', ascending=False)
# Out:
#                    A         B         C         D
# 2013-01-06 -0.364734  1.555375 -0.497573 -0.281790
# 2013-01-01  0.558480  0.863395  1.185102  2.349155
# 2013-01-02 -1.551845  0.286379 -0.229315  0.576123
# 2013-01-05 -1.735809  0.104906  0.588369  1.372278
# 2013-01-04 -0.294955  0.006319  0.918337 -3.084601
# 2013-01-03 -0.358542 -0.355383 -0.067001  0.351484

# %% [markdown]
# ## Selection

# %% [markdown]
# **Note:** While standard Python / Numpy expressions for selecting and setting are intuitive and come in handy for interactive work, for production code, we recommend the optimized pandas data access methods, .at, .iat, .loc, .iloc and .ix.

# %% [markdown]
# See the indexing documentation [Indexing and Selecting Data](http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing) and [MultiIndex / Advanced Indexing](http://pandas.pydata.org/pandas-docs/stable/advanced.html#advanced)

# %% [markdown]
# ### Getting

# %% [markdown]
# Selecting a single column, which yields a Series, equivalent to df.A

# %%
df
# Out:
#                    A         B         C         D
# 2013-01-01  0.558480  0.863395  1.185102  2.349155
# 2013-01-02 -1.551845  0.286379 -0.229315  0.576123
# 2013-01-03 -0.358542 -0.355383 -0.067001  0.351484
# 2013-01-04 -0.294955  0.006319  0.918337 -3.084601
# 2013-01-05 -1.735809  0.104906  0.588369  1.372278
# 2013-01-06 -0.364734  1.555375 -0.497573 -0.281790

# %%
df['A']
# Out:
# 2013-01-01    0.558480
# 2013-01-02   -1.551845
# 2013-01-03   -0.358542
# 2013-01-04   -0.294955
# 2013-01-05   -1.735809
# 2013-01-06   -0.364734
# Freq: D, Name: A, dtype: float64

# %% [markdown]
# Selecting via [], which slices the rows.

# %%
df[0:3]
# Out:
#                    A         B         C         D
# 2013-01-01  0.558480  0.863395  1.185102  2.349155
# 2013-01-02 -1.551845  0.286379 -0.229315  0.576123
# 2013-01-03 -0.358542 -0.355383 -0.067001  0.351484

# %%
df['20130101':'20130103']
# Out:
#                    A         B         C         D
# 2013-01-01  0.558480  0.863395  1.185102  2.349155
# 2013-01-02 -1.551845  0.286379 -0.229315  0.576123
# 2013-01-03 -0.358542 -0.355383 -0.067001  0.351484

# %% [markdown]
# ### Selection by Label
#
# See more in [Selection by Label](Selection by Label)

# %% [markdown]
# For getting a cross section using a label

# %%
df
# Out:
#                    A         B         C         D
# 2013-01-01  0.558480  0.863395  1.185102  2.349155
# 2013-01-02 -1.551845  0.286379 -0.229315  0.576123
# 2013-01-03 -0.358542 -0.355383 -0.067001  0.351484
# 2013-01-04 -0.294955  0.006319  0.918337 -3.084601
# 2013-01-05 -1.735809  0.104906  0.588369  1.372278
# 2013-01-06 -0.364734  1.555375 -0.497573 -0.281790

# %%
dates[0]
# Out:
# Timestamp('2013-01-01 00:00:00')

# %%
df.loc[dates[0]:dates[3], :]
# Out:
#                    A         B         C         D
# 2013-01-01  0.558480  0.863395  1.185102  2.349155
# 2013-01-02 -1.551845  0.286379 -0.229315  0.576123
# 2013-01-03 -0.358542 -0.355383 -0.067001  0.351484
# 2013-01-04 -0.294955  0.006319  0.918337 -3.084601

# %% [markdown]
# Selection by Label

# %%
df.loc[:,['A','C']]
# Out:
#                    A         C
# 2013-01-01  0.558480  1.185102
# 2013-01-02 -1.551845 -0.229315
# 2013-01-03 -0.358542 -0.067001
# 2013-01-04 -0.294955  0.918337
# 2013-01-05 -1.735809  0.588369
# 2013-01-06 -0.364734 -0.497573

# %% [markdown]
# Showing label slicing, both endpoints are included

# %%
df.loc['20130102':'20130104',['A','B']]
# Out:
#                    A         B
# 2013-01-02 -1.551845  0.286379
# 2013-01-03 -0.358542 -0.355383
# 2013-01-04 -0.294955  0.006319

# %% [markdown]
# Reduction in the dimensions of the returned object

# %%
df.loc['20130102',['A','B']] = 1
df
# Out:
#                    A         B         C         D
# 2013-01-01  0.558480  0.863395  1.185102  2.349155
# 2013-01-02  1.000000  1.000000 -0.229315  0.576123
# 2013-01-03 -0.358542 -0.355383 -0.067001  0.351484
# 2013-01-04 -0.294955  0.006319  0.918337 -3.084601
# 2013-01-05 -1.735809  0.104906  0.588369  1.372278
# 2013-01-06 -0.364734  1.555375 -0.497573 -0.281790

# %% [markdown]
# For getting a scalar value

# %%
df.loc[dates[0],'A']
# Out:
# np.float64(0.5584804957477871)

# %%
df
# Out:
#                    A         B         C         D
# 2013-01-01  0.558480  0.863395  1.185102  2.349155
# 2013-01-02  1.000000  1.000000 -0.229315  0.576123
# 2013-01-03 -0.358542 -0.355383 -0.067001  0.351484
# 2013-01-04 -0.294955  0.006319  0.918337 -3.084601
# 2013-01-05 -1.735809  0.104906  0.588369  1.372278
# 2013-01-06 -0.364734  1.555375 -0.497573 -0.281790

# %% [markdown]
# ### Selection by Position
#
# See more in [Selection by Position](http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-integer)

# %% [markdown]
# Select via the position of the passed integers

# %%
df
# Out:
#                    A         B         C         D
# 2013-01-01  0.558480  0.863395  1.185102  2.349155
# 2013-01-02  1.000000  1.000000 -0.229315  0.576123
# 2013-01-03 -0.358542 -0.355383 -0.067001  0.351484
# 2013-01-04 -0.294955  0.006319  0.918337 -3.084601
# 2013-01-05 -1.735809  0.104906  0.588369  1.372278
# 2013-01-06 -0.364734  1.555375 -0.497573 -0.281790

# %%
df.iloc[3] = 2
df
# Out:
#                    A         B         C         D
# 2013-01-01  0.558480  0.863395  1.185102  2.349155
# 2013-01-02  1.000000  1.000000 -0.229315  0.576123
# 2013-01-03 -0.358542 -0.355383 -0.067001  0.351484
# 2013-01-04  2.000000  2.000000  2.000000  2.000000
# 2013-01-05 -1.735809  0.104906  0.588369  1.372278
# 2013-01-06 -0.364734  1.555375 -0.497573 -0.281790

# %% [markdown]
# By integer slices, acting similar to numpy/python

# %%
df.iloc[3:5,0:2] = 5
df
# Out:
#                    A         B         C         D
# 2013-01-01  0.558480  0.863395  1.185102  2.349155
# 2013-01-02  1.000000  1.000000 -0.229315  0.576123
# 2013-01-03 -0.358542 -0.355383 -0.067001  0.351484
# 2013-01-04  5.000000  5.000000  2.000000  2.000000
# 2013-01-05  5.000000  5.000000  0.588369  1.372278
# 2013-01-06 -0.364734  1.555375 -0.497573 -0.281790

# %% [markdown]
# By lists of integer position locations, similar to the numpy/python style

# %%
df.iloc[[1,2,4],[0,2]]
# Out:
#                    A         C
# 2013-01-02  1.000000 -0.229315
# 2013-01-03 -0.358542 -0.067001
# 2013-01-05  5.000000  0.588369

# %% [markdown]
# For slicing rows explicitly

# %%
df.iloc[1:3,:]
# Out:
#                    A         B         C         D
# 2013-01-02  1.000000  1.000000 -0.229315  0.576123
# 2013-01-03 -0.358542 -0.355383 -0.067001  0.351484

# %% [markdown]
# For slicing columns explicitly

# %%
df.iloc[:,1:3]
# Out:
#                    B         C
# 2013-01-01  0.863395  1.185102
# 2013-01-02  1.000000 -0.229315
# 2013-01-03 -0.355383 -0.067001
# 2013-01-04  5.000000  2.000000
# 2013-01-05  5.000000  0.588369
# 2013-01-06  1.555375 -0.497573

# %% [markdown]
# For getting a value explicitly

# %%
df.iloc[1,1]
# Out:
# np.float64(1.0)

# %% [markdown]
# For getting fast access to a scalar (equiv to the prior method)

# %%
df.iat[1,1]
# Out:
# np.float64(1.0)

# %% [markdown]
# ### Multi Indexing

# %%
df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %%
df2.loc[:1,'F'] = 'bar'
df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  bar
# 1  1.0 2013-01-02  1.0  3  train  bar
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %%
df2.set_index(['E', 'F'], inplace=True)
df2.sort_index(inplace=True)
df2
# Out:
#              A          B    C  D
# E     F
# test  bar  1.0 2013-01-02  1.0  3
#       foo  1.0 2013-01-02  1.0  3
# train bar  1.0 2013-01-02  1.0  3
#       foo  1.0 2013-01-02  1.0  3

# %% [markdown]
# ### slicing through multi-indexed dataframe

# %%
df2.iloc[1:5,:]
# Out:
#              A          B    C  D
# E     F
# test  foo  1.0 2013-01-02  1.0  3
# train bar  1.0 2013-01-02  1.0  3
#       foo  1.0 2013-01-02  1.0  3

# %% [markdown]
# ### Using loc on multi-indexed dataframe

# %%
ix = pd.IndexSlice

df2.loc[ix[:,'bar'],:]
# Out:
#              A          B    C  D
# E     F
# test  bar  1.0 2013-01-02  1.0  3
# train bar  1.0 2013-01-02  1.0  3

# %% [markdown]
# ## Boolean Indexing

# %% [markdown]
# Using a single column’s values to select data.

# %%
df
# Out:
#                    A         B         C         D
# 2013-01-01  0.558480  0.863395  1.185102  2.349155
# 2013-01-02  1.000000  1.000000 -0.229315  0.576123
# 2013-01-03 -0.358542 -0.355383 -0.067001  0.351484
# 2013-01-04  5.000000  5.000000  2.000000  2.000000
# 2013-01-05  5.000000  5.000000  0.588369  1.372278
# 2013-01-06 -0.364734  1.555375 -0.497573 -0.281790

# %%
df[df.B > 0]
# Out:
#                    A         B         C         D
# 2013-01-01  0.558480  0.863395  1.185102  2.349155
# 2013-01-02  1.000000  1.000000 -0.229315  0.576123
# 2013-01-04  5.000000  5.000000  2.000000  2.000000
# 2013-01-05  5.000000  5.000000  0.588369  1.372278
# 2013-01-06 -0.364734  1.555375 -0.497573 -0.281790

# %% [markdown]
# A where operation for getting.

# %%
df[df > 0]
# Out:
#                   A         B         C         D
# 2013-01-01  0.55848  0.863395  1.185102  2.349155
# 2013-01-02  1.00000  1.000000       NaN  0.576123
# 2013-01-03      NaN       NaN       NaN  0.351484
# 2013-01-04  5.00000  5.000000  2.000000  2.000000
# 2013-01-05  5.00000  5.000000  0.588369  1.372278
# 2013-01-06      NaN  1.555375       NaN       NaN

# %% [markdown]
# Using the isin() method for filtering:

# %%
df2 = df.copy()
df2
# Out:
#                    A         B         C         D
# 2013-01-01  0.558480  0.863395  1.185102  2.349155
# 2013-01-02  1.000000  1.000000 -0.229315  0.576123
# 2013-01-03 -0.358542 -0.355383 -0.067001  0.351484
# 2013-01-04  5.000000  5.000000  2.000000  2.000000
# 2013-01-05  5.000000  5.000000  0.588369  1.372278
# 2013-01-06 -0.364734  1.555375 -0.497573 -0.281790

# %%
df2['E'] = ['one','one', 'two','three','four','three']

# %%
df2
# Out:
#                    A         B         C         D      E
# 2013-01-01  0.558480  0.863395  1.185102  2.349155    one
# 2013-01-02  1.000000  1.000000 -0.229315  0.576123    one
# 2013-01-03 -0.358542 -0.355383 -0.067001  0.351484    two
# 2013-01-04  5.000000  5.000000  2.000000  2.000000  three
# 2013-01-05  5.000000  5.000000  0.588369  1.372278   four
# 2013-01-06 -0.364734  1.555375 -0.497573 -0.281790  three

# %%
df2[df2['E'].isin(['two','four'])]
# Out:
#                    A         B         C         D     E
# 2013-01-03 -0.358542 -0.355383 -0.067001  0.351484   two
# 2013-01-05  5.000000  5.000000  0.588369  1.372278  four

# %% [markdown]
# ## Setting

# %% [markdown]
# Setting a new column automatically aligns the data by the indexes

# %%
s1 = pd.Series([1,2,3,4,5,6], index=pd.date_range('20130102',periods=6))

# %%
s1
# Out:
# 2013-01-02    1
# 2013-01-03    2
# 2013-01-04    3
# 2013-01-05    4
# 2013-01-06    5
# 2013-01-07    6
# Freq: D, dtype: int64

# %%
df['F'] = s1
df
# Out:
#                    A         B         C         D    F
# 2013-01-01  0.558480  0.863395  1.185102  2.349155  NaN
# 2013-01-02  1.000000  1.000000 -0.229315  0.576123  1.0
# 2013-01-03 -0.358542 -0.355383 -0.067001  0.351484  2.0
# 2013-01-04  5.000000  5.000000  2.000000  2.000000  3.0
# 2013-01-05  5.000000  5.000000  0.588369  1.372278  4.0
# 2013-01-06 -0.364734  1.555375 -0.497573 -0.281790  5.0

# %% [markdown]
# Setting values by label

# %%
df.at[dates[0],'A'] = 0
df
# Out:
#                    A         B         C         D    F
# 2013-01-01  0.000000  0.863395  1.185102  2.349155  NaN
# 2013-01-02  1.000000  1.000000 -0.229315  0.576123  1.0
# 2013-01-03 -0.358542 -0.355383 -0.067001  0.351484  2.0
# 2013-01-04  5.000000  5.000000  2.000000  2.000000  3.0
# 2013-01-05  5.000000  5.000000  0.588369  1.372278  4.0
# 2013-01-06 -0.364734  1.555375 -0.497573 -0.281790  5.0

# %% [markdown]
# Settomg values by position

# %%
df.iat[0,1] = 0
df
# Out:
#                    A         B         C         D    F
# 2013-01-01  0.000000  0.000000  1.185102  2.349155  NaN
# 2013-01-02  1.000000  1.000000 -0.229315  0.576123  1.0
# 2013-01-03 -0.358542 -0.355383 -0.067001  0.351484  2.0
# 2013-01-04  5.000000  5.000000  2.000000  2.000000  3.0
# 2013-01-05  5.000000  5.000000  0.588369  1.372278  4.0
# 2013-01-06 -0.364734  1.555375 -0.497573 -0.281790  5.0

# %% [markdown]
# Setting by assigning with a numpy array

# %%
df.loc[:,'D'] = np.array([5] * len(df))
df
# Out:
#                    A         B         C    D    F
# 2013-01-01  0.000000  0.000000  1.185102  5.0  NaN
# 2013-01-02  1.000000  1.000000 -0.229315  5.0  1.0
# 2013-01-03 -0.358542 -0.355383 -0.067001  5.0  2.0
# 2013-01-04  5.000000  5.000000  2.000000  5.0  3.0
# 2013-01-05  5.000000  5.000000  0.588369  5.0  4.0
# 2013-01-06 -0.364734  1.555375 -0.497573  5.0  5.0

# %% [markdown]
# The result of the prior setting operations

# %%
df
# Out:
#                    A         B         C    D    F
# 2013-01-01  0.000000  0.000000  1.185102  5.0  NaN
# 2013-01-02  1.000000  1.000000 -0.229315  5.0  1.0
# 2013-01-03 -0.358542 -0.355383 -0.067001  5.0  2.0
# 2013-01-04  5.000000  5.000000  2.000000  5.0  3.0
# 2013-01-05  5.000000  5.000000  0.588369  5.0  4.0
# 2013-01-06 -0.364734  1.555375 -0.497573  5.0  5.0

# %% [markdown]
# A where operation with setting.

# %%
df2 = df.copy()
df2
# Out:
#                    A         B         C    D    F
# 2013-01-01  0.000000  0.000000  1.185102  5.0  NaN
# 2013-01-02  1.000000  1.000000 -0.229315  5.0  1.0
# 2013-01-03 -0.358542 -0.355383 -0.067001  5.0  2.0
# 2013-01-04  5.000000  5.000000  2.000000  5.0  3.0
# 2013-01-05  5.000000  5.000000  0.588369  5.0  4.0
# 2013-01-06 -0.364734  1.555375 -0.497573  5.0  5.0

# %%
df2[df2 > 0] = -df2
df2
# Out:
#                    A         B         C    D    F
# 2013-01-01  0.000000  0.000000 -1.185102 -5.0  NaN
# 2013-01-02 -1.000000 -1.000000 -0.229315 -5.0 -1.0
# 2013-01-03 -0.358542 -0.355383 -0.067001 -5.0 -2.0
# 2013-01-04 -5.000000 -5.000000 -2.000000 -5.0 -3.0
# 2013-01-05 -5.000000 -5.000000 -0.588369 -5.0 -4.0
# 2013-01-06 -0.364734 -1.555375 -0.497573 -5.0 -5.0

# %% [markdown]
# ## Missing Data
#
# pandas primarily uses the value np.nan to represent missing data. It is by default not included in computations. See the Missing Data section

# %% [markdown]
# Reindexing allows you to change/add/delete the index on a specified axis. This returns a copy of the data.

# %%
df
# Out:
#                    A         B         C    D    F
# 2013-01-01  0.000000  0.000000  1.185102  5.0  NaN
# 2013-01-02  1.000000  1.000000 -0.229315  5.0  1.0
# 2013-01-03 -0.358542 -0.355383 -0.067001  5.0  2.0
# 2013-01-04  5.000000  5.000000  2.000000  5.0  3.0
# 2013-01-05  5.000000  5.000000  0.588369  5.0  4.0
# 2013-01-06 -0.364734  1.555375 -0.497573  5.0  5.0

# %%
df1 = df.reindex(index=dates[0:4], columns=list(df.columns) + ['E'])
df1
# Out:
#                    A         B         C    D    F   E
# 2013-01-01  0.000000  0.000000  1.185102  5.0  NaN NaN
# 2013-01-02  1.000000  1.000000 -0.229315  5.0  1.0 NaN
# 2013-01-03 -0.358542 -0.355383 -0.067001  5.0  2.0 NaN
# 2013-01-04  5.000000  5.000000  2.000000  5.0  3.0 NaN

# %%
df1.loc[dates[0]:dates[1],'E'] = 1
df1
# Out:
#                    A         B         C    D    F    E
# 2013-01-01  0.000000  0.000000  1.185102  5.0  NaN  1.0
# 2013-01-02  1.000000  1.000000 -0.229315  5.0  1.0  1.0
# 2013-01-03 -0.358542 -0.355383 -0.067001  5.0  2.0  NaN
# 2013-01-04  5.000000  5.000000  2.000000  5.0  3.0  NaN

# %%
df1
# Out:
#                    A         B         C    D    F   E
# 2013-01-01  0.000000  0.000000  1.185102  5.0  NaN NaN
# 2013-01-02  1.000000  1.000000 -0.229315  5.0  1.0 NaN
# 2013-01-03 -0.358542 -0.355383 -0.067001  5.0  2.0 NaN
# 2013-01-04  5.000000  5.000000  2.000000  5.0  3.0 NaN

# %% [markdown]
# To drop any rows that have missing data.

# %%
df1.dropna(how='all', axis=1)
# Out:
#                    A         B         C    D    F
# 2013-01-01  0.000000  0.000000  1.185102  5.0  NaN
# 2013-01-02  1.000000  1.000000 -0.229315  5.0  1.0
# 2013-01-03 -0.358542 -0.355383 -0.067001  5.0  2.0
# 2013-01-04  5.000000  5.000000  2.000000  5.0  3.0

# %% [markdown]
# Filling missing data

# %%
df1
# Out:
#                    A         B         C    D    F   E
# 2013-01-01  0.000000  0.000000  1.185102  5.0  NaN NaN
# 2013-01-02  1.000000  1.000000 -0.229315  5.0  1.0 NaN
# 2013-01-03 -0.358542 -0.355383 -0.067001  5.0  2.0 NaN
# 2013-01-04  5.000000  5.000000  2.000000  5.0  3.0 NaN

# %%
df1 = df1.fillna(value=5)
df1
# Out:
#                    A         B         C    D    F    E
# 2013-01-01  0.000000  0.000000  1.185102  5.0  5.0  5.0
# 2013-01-02  1.000000  1.000000 -0.229315  5.0  1.0  5.0
# 2013-01-03 -0.358542 -0.355383 -0.067001  5.0  2.0  5.0
# 2013-01-04  5.000000  5.000000  2.000000  5.0  3.0  5.0

# %% [markdown]
# To get the boolean mask where values are nan

# %%
pd.isnull(df1).sum(axis=1)
# Out:
# 2013-01-01    2
# 2013-01-02    1
# 2013-01-03    1
# 2013-01-04    1
# Freq: D, dtype: int64

# %% [markdown]
# ## Operations
#
# See the [Basic section on Binary Ops](http://pandas.pydata.org/pandas-docs/stable/basics.html#basics-binop)

# %%
df
# Out:
#                    A         B         C    D    F
# 2013-01-01  0.000000  0.000000  1.185102  5.0  NaN
# 2013-01-02  1.000000  1.000000 -0.229315  5.0  1.0
# 2013-01-03 -0.358542 -0.355383 -0.067001  5.0  2.0
# 2013-01-04  5.000000  5.000000  2.000000  5.0  3.0
# 2013-01-05  5.000000  5.000000  0.588369  5.0  4.0
# 2013-01-06 -0.364734  1.555375 -0.497573  5.0  5.0

# %% [markdown]
# ### Stats
#
# Operations in general exclude missing data.

# %% [markdown]
# Performing a descriptive statistic

# %%
df.max()
# Out:
# A    5.0
# B    5.0
# C    2.0
# D    5.0
# F    5.0
# dtype: float64

# %% [markdown]
# Same operation on the other axis

# %%
df.mean(axis=1)
# Out:
# 2013-01-01    1.546275
# 2013-01-02    1.554137
# 2013-01-03    1.243815
# 2013-01-04    4.000000
# 2013-01-05    3.917674
# 2013-01-06    2.138614
# Freq: D, dtype: float64

# %% [markdown]
# Operating with objects that have different dimensionality and need alignment. In addition, pandas automatically broadcasts along the specified dimension.

# %%
s = pd.Series([1,3,5,np.nan,6,8], index=dates)#.shift(2)

# %%
s
# Out:
# 2013-01-01    1.0
# 2013-01-02    3.0
# 2013-01-03    5.0
# 2013-01-04    NaN
# 2013-01-05    6.0
# 2013-01-06    8.0
# Freq: D, dtype: float64

# %%
s.shift(1)
# Out:
# 2013-01-01    NaN
# 2013-01-02    1.0
# 2013-01-03    3.0
# 2013-01-04    5.0
# 2013-01-05    NaN
# 2013-01-06    6.0
# Freq: D, dtype: float64

# %%
df
# Out:
#                    A         B         C    D    F
# 2013-01-01  0.000000  0.000000  1.185102  5.0  NaN
# 2013-01-02  1.000000  1.000000 -0.229315  5.0  1.0
# 2013-01-03 -0.358542 -0.355383 -0.067001  5.0  2.0
# 2013-01-04  5.000000  5.000000  2.000000  5.0  3.0
# 2013-01-05  5.000000  5.000000  0.588369  5.0  4.0
# 2013-01-06 -0.364734  1.555375 -0.497573  5.0  5.0

# %%
df.subtract(s, axis='index')
# Out:
#                    A         B         C    D    F
# 2013-01-01 -1.000000 -1.000000  0.185102  4.0  NaN
# 2013-01-02 -2.000000 -2.000000 -3.229315  2.0 -2.0
# 2013-01-03 -5.358542 -5.355383 -5.067001  0.0 -3.0
# 2013-01-04       NaN       NaN       NaN  NaN  NaN
# 2013-01-05 -1.000000 -1.000000 -5.411631 -1.0 -2.0
# 2013-01-06 -8.364734 -6.444625 -8.497573 -3.0 -3.0

# %%
df.sub(s, axis='index')
# Out:
#                    A         B         C    D    F
# 2013-01-01 -1.000000 -1.000000  0.185102  4.0  NaN
# 2013-01-02 -2.000000 -2.000000 -3.229315  2.0 -2.0
# 2013-01-03 -5.358542 -5.355383 -5.067001  0.0 -3.0
# 2013-01-04       NaN       NaN       NaN  NaN  NaN
# 2013-01-05 -1.000000 -1.000000 -5.411631 -1.0 -2.0
# 2013-01-06 -8.364734 -6.444625 -8.497573 -3.0 -3.0

# %% [markdown]
# ### Apply

# %% [markdown]
# Applying functions to the data

# %%
df
# Out:
#                    A         B         C    D    F
# 2013-01-01  0.000000  0.000000  1.185102  5.0  NaN
# 2013-01-02  1.000000  1.000000 -0.229315  5.0  1.0
# 2013-01-03 -0.358542 -0.355383 -0.067001  5.0  2.0
# 2013-01-04  5.000000  5.000000  2.000000  5.0  3.0
# 2013-01-05  5.000000  5.000000  0.588369  5.0  4.0
# 2013-01-06 -0.364734  1.555375 -0.497573  5.0  5.0

# %%
df.cumsum()
# Out:
#                     A          B         C     D     F
# 2013-01-01   0.000000   0.000000  1.185102   5.0   NaN
# 2013-01-02   1.000000   1.000000  0.955787  10.0   1.0
# 2013-01-03   0.641458   0.644617  0.888786  15.0   3.0
# 2013-01-04   5.641458   5.644617  2.888786  20.0   6.0
# 2013-01-05  10.641458  10.644617  3.477155  25.0  10.0
# 2013-01-06  10.276724  12.199993  2.979581  30.0  15.0

# %%
df.apply(np.cumsum)
# Out:
#                     A          B         C     D     F
# 2013-01-01   0.000000   0.000000  1.185102   5.0   NaN
# 2013-01-02   1.000000   1.000000  0.955787  10.0   1.0
# 2013-01-03   0.641458   0.644617  0.888786  15.0   3.0
# 2013-01-04   5.641458   5.644617  2.888786  20.0   6.0
# 2013-01-05  10.641458  10.644617  3.477155  25.0  10.0
# 2013-01-06  10.276724  12.199993  2.979581  30.0  15.0

# %%
df
# Out:
#                    A         B         C    D    F
# 2013-01-01  0.000000  0.000000  1.185102  5.0  NaN
# 2013-01-02  1.000000  1.000000 -0.229315  5.0  1.0
# 2013-01-03 -0.358542 -0.355383 -0.067001  5.0  2.0
# 2013-01-04  5.000000  5.000000  2.000000  5.0  3.0
# 2013-01-05  5.000000  5.000000  0.588369  5.0  4.0
# 2013-01-06 -0.364734  1.555375 -0.497573  5.0  5.0

# %%
df.apply(lambda x: x.max() - x.min(), axis=1)
# Out:
# 2013-01-01    5.000000
# 2013-01-02    5.229315
# 2013-01-03    5.358542
# 2013-01-04    3.000000
# 2013-01-05    4.411631
# 2013-01-06    5.497573
# Freq: D, dtype: float64

# %% [markdown]
# ### Histogramming
#
# See more at [Histogramming and Discretization](http://pandas.pydata.org/pandas-docs/stable/basics.html#basics-discretization)

# %%
s = pd.Series(np.random.randint(0, 7, size=10))

# %%
s
# Out:
# 0    1
# 1    5
# 2    4
# 3    5
# 4    3
# 5    3
# 6    4
# 7    0
# 8    6
# 9    2
# dtype: int64

# %%
s.value_counts()
# Out:
# 5    2
# 4    2
# 3    2
# 1    1
# 0    1
# 6    1
# 2    1
# Name: count, dtype: int64

# %% [markdown]
# ### String Methods
#
# Series is equipped with a set of string processing methods in the str attribute that make it easy to operate on each element of the array, as in the code snippet below. Note that pattern-matching in str generally uses [regular expressions](https://docs.python.org/2/library/re.html) by default (and in some cases always uses them). See more at [Vectorized String Methods](http://pandas.pydata.org/pandas-docs/stable/text.html#text-string-methods).

# %%
s = pd.Series(['A', 'B', 'C', 'Aaba', 'Baca', np.nan, 'CABA', 'dog', 'cat'])

# %%
s
# Out:
# 0       A
# 1       B
# 2       C
# 3    Aaba
# 4    Baca
# 5     NaN
# 6    CABA
# 7     dog
# 8     cat
# dtype: str

# %%
s.str.lower()
# Out:
# 0       a
# 1       b
# 2       c
# 3    aaba
# 4    baca
# 5     NaN
# 6    caba
# 7     dog
# 8     cat
# dtype: str

# %% [markdown]
# ## Merge

# %% [markdown]
# ### Concat
#
# pandas provides various facilities for easily combining together Series, DataFrame, and Panel objects with various kinds of set logic for the indexes and relational algebra functionality in the case of join / merge-type operations.
#
# See the [Merging section](http://pandas.pydata.org/pandas-docs/stable/merging.html#merging)

# %% [markdown]
# Concatenating pandas objects together with concat():

# %%
df = pd.DataFrame(np.random.randn(10, 4))

# %%
df
# Out:
#           0         1         2         3
# 0  1.200995  2.048899 -1.741123 -0.427735
# 1  0.700132 -1.109827 -0.900336  0.202431
# 2 -1.849280  0.751738  0.272343  0.890525
# 3 -0.010421  1.121221  1.676275  0.012746
# 4  0.767540  0.523605 -0.194881  1.571361
# 5  0.443993  1.099494 -0.272406 -0.189431
# 6  0.247823 -0.201347  1.322933 -2.046874
# 7  0.635649 -1.185583 -1.070426 -0.483053
# 8  0.209484 -0.239818 -1.022772 -0.778014
# 9  0.347978  1.613065 -0.149587  0.901365

# %%
# break it into pieces
pieces = [df[:3], df[3:7], df[7:]]
pieces
# Out:
# [          0         1         2         3
#  0  1.200995  2.048899 -1.741123 -0.427735
#  1  0.700132 -1.109827 -0.900336  0.202431
#  2 -1.849280  0.751738  0.272343  0.890525,
#            0         1         2         3
#  3 -0.010421  1.121221  1.676275  0.012746
#  4  0.767540  0.523605 -0.194881  1.571361
#  5  0.443993  1.099494 -0.272406 -0.189431
#  6  0.247823 -0.201347  1.322933 -2.046874,
#            0         1         2         3
#  7  0.635649 -1.185583 -1.070426 -0.483053
#  8  0.209484 -0.239818 -1.022772 -0.778014
#  9  0.347978  1.613065 -0.149587  0.901365]

# %%
pd.concat(pieces)
# Out:
#           0         1         2         3
# 0  1.200995  2.048899 -1.741123 -0.427735
# 1  0.700132 -1.109827 -0.900336  0.202431
# 2 -1.849280  0.751738  0.272343  0.890525
# 3 -0.010421  1.121221  1.676275  0.012746
# 4  0.767540  0.523605 -0.194881  1.571361
# 5  0.443993  1.099494 -0.272406 -0.189431
# 6  0.247823 -0.201347  1.322933 -2.046874
# 7  0.635649 -1.185583 -1.070426 -0.483053
# 8  0.209484 -0.239818 -1.022772 -0.778014
# 9  0.347978  1.613065 -0.149587  0.901365

# %% [markdown]
# ### Join
#
# SQL style merges. See the [Database style joining](http://pandas.pydata.org/pandas-docs/stable/merging.html#merging-join)

# %%
left = pd.DataFrame({'key': ['foo', 'bar'], 'lval': [1, 2]})
left
# Out:
#    key  lval
# 0  foo     1
# 1  bar     2

# %%
right = pd.DataFrame({'key': ['foo', 'bah'], 'rval': [4, 5]})
right
# Out:
#    key  rval
# 0  foo     4
# 1  bah     5

# %%
pd.merge(left, right, on='key', how='outer')
# Out:
#    key  lval  rval
# 0  bah   NaN   5.0
# 1  bar   2.0   NaN
# 2  foo   1.0   4.0

# %% [markdown]
# ### Append
#
# Append rows to a dataframe. See the [Appending](http://pandas.pydata.org/pandas-docs/stable/merging.html#merging-concatenation)

# %%
df = pd.DataFrame(np.random.randn(8, 4), columns=['A','B','C','D'])

# %%
df
# Out:
#           A         B         C         D
# 0  0.128202 -0.266027 -0.315476  1.288523
# 1  0.410634  0.550474 -0.995326  0.079052
# 2  2.230548  1.088229 -1.666740  1.040301
# 3 -0.071123  2.540147  0.025697  0.284285
# 4 -0.188029  0.926822 -0.028452  0.128850
# 5 -0.175392  0.609868 -1.515990 -0.468709
# 6  0.058263 -0.336982  0.092620 -0.797268
# 7  0.383426 -0.367014  0.510464 -1.278034

# %%
s = df.iloc[3]
s

# %% [markdown]
# ## Grouping
#
# By “group by” we are referring to a process involving one or more of the following steps
#
# * **Splitting** the data into groups based on some criteria
# * **Applying** a function to each group independently
# * **Combining** the results into a data structure
#
# See the [Grouping section](http://pandas.pydata.org/pandas-docs/stable/groupby.html#groupby)

# %%
df = pd.DataFrame({'A' : ['foo', 'bar', 'foo', 'bar', 'foo', 'bar', 'foo', 'foo'],
                                    'B' : ['one', 'one', 'two', 'three','two', 'two', 'one', 'three'],
                                    'C' : np.random.randn(8),
                                     'D' : np.random.randn(8)})
df

# %%
df.set_index(['A', 'B']).sort_index()

# %% [markdown]
# Grouping and then applying a function sum to the resulting groups.

# %%
df.groupby(['A', 'B']).max()

# %%
df.groupby('A').sum()

# %%
df.groupby(['A','B']).sum()

# %%
df.set_index(['A', 'B']).sort_index()

# %%
df.groupby(['A', 'B']).describe()

# %% [markdown]
# ## Reshaping
#
# See the sections on [Hierarchical Indexing](http://pandas.pydata.org/pandas-docs/stable/advanced.html#advanced-hierarchical) and [Reshaping](http://pandas.pydata.org/pandas-docs/stable/reshaping.html#reshaping-stacking).

# %% [markdown]
# ### Stack

# %%
tuples = list(zip(
    *[['bar', 'bar', 'baz', 'baz', 'foo', 'foo', 'qux', 'qux'],
      ['one', 'two', 'one', 'two', 'one', 'two', 'one', 'two']]))
tuples

# %%
index = pd.MultiIndex.from_tuples(tuples, names=['first', 'second'])
index

# %%
df = pd.DataFrame(np.random.randn(8, 2), index=index, columns=['A', 'B'])
df

# %%
df2 = df[:4]

# %%
df2

# %% [markdown]
# The stack() method “compresses” a level in the DataFrame’s columns.

# %%
stacked = df2.stack()

# %%
stacked

# %% [markdown]
# With a “stacked” DataFrame or Series (having a MultiIndex as the index), the inverse operation of stack() is unstack(), which by default unstacks the **last level**:

# %%
stacked.unstack()

# %%
stacked.unstack(1)

# %%
stacked.unstack(0)

# %% [markdown]
# ### Pivot Tables
#
# See the section on [Pivot Tables](http://pandas.pydata.org/pandas-docs/stable/reshaping.html#reshaping-pivot).

# %%
df = pd.DataFrame({'A' : ['one', 'one', 'two', 'three'] * 3,
                                    'B' : ['A', 'B', 'C'] * 4,
                                    'C' : ['foo', 'foo', 'foo', 'bar', 'bar', 'bar'] * 2,
                                    'D' : np.random.randn(12),
                                    'E' : np.random.randn(12)})

# %%
df

# %% [markdown]
# We can produce pivot tables from this data very easily:

# %%
pd.pivot_table(df, values='D', index=['A', 'B'], columns=['C'])

# %% [markdown]
# ## Time Series
#
# pandas has simple, powerful, and efficient functionality for performing resampling operations during frequency conversion (e.g., converting secondly data into 5-minutely data). This is extremely common in, but not limited to, financial applications. See the [Time Series section](http://pandas.pydata.org/pandas-docs/stable/timeseries.html#timeseries)

# %%
# pd.date_range?

# %%
rng = pd.date_range('1/1/2012', periods=100, freq='1s')
rng

# %%
ts = pd.Series(np.random.randint(0, 500, len(rng)), index=rng)
ts

# %%
# ts.resample?

# %%
ts.resample('1Min').sum()

# %% [markdown]
# Time zone representation

# %%
rng = pd.date_range('3/6/2012 00:00', periods=5, freq='D')

# %%
ts = pd.Series(np.random.randn(len(rng)), rng)

# %%
ts

# %%
ts_utc = ts.tz_localize('UTC')

# %%
ts_utc

# %% [markdown]
# Convert to another time zone

# %%
ts_utc.tz_convert('US/Eastern')

# %% [markdown]
# Converting between time span representations

# %%
rng = pd.date_range('1/1/2012', periods=5, freq='ME')

# %%
ts = pd.Series(np.random.randn(len(rng)), index=rng)

# %%
ts

# %%
ps = ts.to_period()

# %%
ps

# %%
ps.to_timestamp()

# %% [markdown]
# Converting between period and timestamp enables some convenient arithmetic functions to be used. In the following example, we convert a quarterly frequency with year ending in November to 9am of the end of the month following the quarter end:

# %%
prng = pd.period_range('1990Q1', '2000Q4', freq='Q-NOV')
prng

# %%
ts = pd.Series(np.random.randn(len(prng)), prng)
ts

# %% [markdown]
# ## Plotting
# [Plotting](http://pandas.pydata.org/pandas-docs/stable/visualization.html#visualization) docs.

# %%
ts = pd.Series(np.random.randn(1000), index=pd.date_range('1/1/2000', periods=1000))

# %%
ts = ts.cumsum()

# %%
ts.plot()

# %% [markdown]
# On DataFrame, plot() is a convenience to plot all of the columns with labels:

# %%
df = pd.DataFrame(np.random.randn(1000, 4), index=ts.index,
                  columns=['A', 'B', 'C', 'D'])

# %%
df = df.cumsum()

# %%
plt.figure(); df.plot(); plt.legend(loc='best')

# %% [markdown]
# ## Getting Data In/Out

# %% [markdown]
# ### CSV
# [Writing to a csv file](http://pandas.pydata.org/pandas-docs/stable/io.html#io-store-in-csv)

# %%
df.to_csv('foo.csv')

# %% [markdown]
# [Reading from a csv file](http://pandas.pydata.org/pandas-docs/stable/io.html#io-read-csv-table)

# %%
pd.read_csv('foo.csv')

# %% [markdown]
# #### Reading large CSV files

# %%
iterator = pd.read_csv('foo.csv', iterator=True, chunksize=3)
iterator

# %%
iterator.get_chunk()
